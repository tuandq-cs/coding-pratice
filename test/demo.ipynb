# %%
import pandas as pd

# %%
raw_data = pd.read_csv('IPL2.csv')
raw_data.head()
# Out:
#   stock  group  free_float  instrument_volumn  close_price
# 0   FPT      1        0.85         1269968875        92800
# 1   HPG      5        0.55         5814785700        26300
# 2   VNM      5        0.40         2089955445        74200
# 3   MWG      5        0.75         1462560047        52600
# 4   MSN      1        0.45         1423724783        76300

# %%
raw_data.columns
# Out:
# Index(['stock', 'group', 'free_float', 'instrument_volumn', 'close_price'], dtype='object')

# %%
raw_data['test_capital'] = raw_data['capital'].astype(int)
raw_data.head()
# Out:
#   stock  group  free_float  instrument_volumn  close_price       capital  \
# 0   FPT      1        0.85         1269968875        92800  1.001751e+14
# 1   HPG      5        0.55         5814785700        26300  8.411088e+13
# 2   VNM      5        0.40         2089955445        74200  6.202988e+13
# 3   MWG      5        0.75         1462560047        52600  5.769799e+13
# 4   MSN      1        0.45         1423724783        76300  4.888359e+13
#
#    raw_weight  adjust_weight1  adjust_weight2     test_capital
# 0    0.170640             0.1        0.098564  100175144860000
# 1    0.143276             0.1        0.090425   84110875150500
# 2    0.105663             0.1        0.090425   62029877607600
# 3    0.098284             0.1        0.090425   57697993854150
# 4    0.083269             0.1        0.098564   48883590424305

# %%
raw_data['capital'] = raw_data['free_float'] * raw_data['instrument_volumn'] * raw_data['close_price']
raw_data['capital'].astype(int)
raw_data['raw_weight'] = raw_data['capital'] / raw_data['capital'].sum()
raw_data.head()
# Out:
#   stock  group  free_float  instrument_volumn  close_price       capital  \
# 0   FPT      1        0.85         1269968875        92800  1.001751e+14
# 1   HPG      5        0.55         5814785700        26300  8.411088e+13
# 2   VNM      5        0.40         2089955445        74200  6.202988e+13
# 3   MWG      5        0.75         1462560047        52600  5.769799e+13
# 4   MSN      1        0.45         1423724783        76300  4.888359e+13
#
#    raw_weight
# 0    0.170640
# 1    0.143276
# 2    0.105663
# 3    0.098284
# 4    0.083269

# %%
from typing import List


def getGroupWeight(groups, weights):
    gWeight = {}
    for i in range(len(weights)):
        g = groups[i]
        if gWeight.get(g) is None:
            gWeight[g] = 0
        gWeight[g] += weights[i]
    return gWeight


def balanceWeights(groups: List[int], weights: List[float], visited: set):
    residual = 0
    remainSum = 0
    for i in range(len(weights)):
        if groups[i] in visited:
            continue
        if weights[i] >= 0.1:
            residual += weights[i] - 0.1
            weights[i] = 0.1
        else:
            remainSum += weights[i]
    for i in range(len(weights)):
        if groups[i] in visited:
            continue
        if weights[i] < 0.1:
            weights[i] = weights[i] * \
                (residual+remainSum) / remainSum
    return residual


def adjustWeights(groups: List[int], weights: List[float], visited: set):
    while True:
        if balanceWeights(groups, weights, visited) == 0:
            break
    return weights


def balanceGroups(groups: List[int], weights: List[float], visited: set):
    adjustWeights(groups, weights, visited)
    gWeight = getGroupWeight(groups, weights)
    residual = 0
    remainSum = 0
    for g in gWeight:
        if g in visited:
            continue
        if gWeight[g] >= 0.3:
            residual += gWeight[g] - 0.3
            visited.add(g)
        else:
            remainSum += gWeight[g]
    for i in range(len(weights)):
        if groups[i] in visited:
            continue
        if weights[i] == 0.1:
            remainSum -= 0.1

    for i in range(len(weights)):
        if groups[i] in visited:
            weights[i] *= 0.3 / gWeight[groups[i]]
            continue
        if gWeight[groups[i]] < 0.3 and weights[i] < 0.1:
            weights[i] = weights[i] * \
                (residual+remainSum) / remainSum
    return residual


def adjustGroups(groups: List[int], weights: List[float]) -> List[float]:
    if len(weights) < 10:
        return []
    gWeight = getGroupWeight(groups, weights)
    visited = set()
    while len(visited) < len(gWeight):
        if balanceGroups(groups, weights, visited) == 0:
            break
    return weights

# %%
raw_data.to_csv('result2.csv')

# %%
weights = raw_data['raw_weight'].to_list()
groups = raw_data['group'].to_list()
raw_data['adjust_weight1'] = pd.Series(adjustWeights(groups, weights, {}))
raw_data['adjust_weight2'] = pd.Series(adjustGroups(groups, weights))
raw_data
# Out:
#    stock  group  free_float  instrument_volumn  close_price       capital  \
# 0    FPT      1        0.85         1269968875        92800  1.001751e+14
# 1    HPG      5        0.55         5814785700        26300  8.411088e+13
# 2    VNM      5        0.40         2089955445        74200  6.202988e+13
# 3    MWG      5        0.75         1462560047        52600  5.769799e+13
# 4    MSN      1        0.45         1423724783        76300  4.888359e+13
# 5    PNJ      4        0.85          650000000        78800  4.353700e+13
# 6    GMD      1        0.90          301377957        66300  1.798322e+13
# 7    GEX      2        0.70          851495793        20800  1.239778e+13
# 8    DIG      4        0.80          609851995        25100  1.224583e+13
# 9    HSG      3        0.85          615982309        20000  1.047170e+13
# 10   REE      1        0.40          408706345        63200  1.033210e+13
# 11   IDC      2        0.65          329999929        46300  9.931348e+12
# 12   KDC      2        0.60          257224010        64200  9.908269e+12
# 13   HUT      2        0.90          348631965        24500  7.687335e+12
# 14   VHC      3        0.50          183376956        78900  7.234221e+12
# 15   FRT      5        0.55          136242389        89000  6.669065e+12
# 16   DPM      3        0.45          391334260        36900  6.498105e+12
# 17   VCG      1        0.50          534465514        24150  6.453671e+12
# 18   DGW      3        0.55          163072974        57900  5.193059e+12
# 19   SAB      1        0.11          641281186        72500  5.114217e+12
# 20   PC1      3        0.60          270433002        30900  5.013828e+12
# 21   CII      2        0.90          284019513        19300  4.933419e+12
# 22   SBT      2        0.45          740500993        14650  4.881753e+12
# 23   TCH      4        0.60          668215843        11600  4.650782e+12
# 24   DCM      5        0.25          529400000        32750  4.334462e+12
# 25   HHV      4        0.80          329350351        15750  4.149814e+12
# 26   HDG      5        0.45          305757372        28150  3.873182e+12
# 27   DBC      4        0.70          242001859        21900  3.709888e+12
# 28   BCG      3        0.70          533467622         9880  3.689462e+12
# 29   BMP      2        0.45           81860938        86000  3.168018e+12
# 30   CTR      4        0.35          114385879        77900  3.118731e+12
# 31   HAH      2        0.70          105517000        38800  2.865842e+12
# 32   PAN      2        0.65          208894750        20350  2.763155e+12
# 33   VGC      1        0.12          448350000        46400  2.496413e+12
# 34   PHR      3        0.35          135499198        47400  2.247932e+12
# 35   CTD      1        0.55           74414258        47800  1.956351e+12
# 36   SZC      3        0.45          120000000        35350  1.908900e+12
# 37   ANV      1        0.30          133127875        36000  1.437781e+12
# 38   HT1      4        0.25          381589911        13650  1.302176e+12
#
#     raw_weight  adjust_weight1  adjust_weight2
# 0     0.170640        0.100000        0.098564
# 1     0.143276        0.100000        0.090425
# 2     0.105663        0.100000        0.090425
# 3     0.098284        0.100000        0.090425
# 4     0.083269        0.100000        0.098564
# 5     0.074162        0.092965        0.100000
# 6     0.030633        0.038400        0.040416
# 7     0.021119        0.026473        0.028617
# 8     0.020860        0.026149        0.028266
# 9     0.017838        0.022360        0.024171
# 10    0.017600        0.022062        0.023221
# 11    0.016917        0.021206        0.022924
# 12    0.016878        0.021157        0.022870
# 13    0.013095        0.016415        0.017744
# 14    0.012323        0.015447        0.016698
# 15    0.011360        0.014240        0.012877
# 16    0.011069        0.013875        0.014999
# 17    0.010993        0.013781        0.014504
# 18    0.008846        0.011089        0.011987
# 19    0.008712        0.010920        0.011494
# 20    0.008541        0.010706        0.011573
# 21    0.008404        0.010534        0.011387
# 22    0.008316        0.010424        0.011268
# 23    0.007922        0.009931        0.010735
# 24    0.007383        0.009255        0.008369
# 25    0.007069        0.008861        0.009579
# 26    0.006598        0.008270        0.007479
# 27    0.006319        0.007922        0.008563
# 28    0.006285        0.007878        0.008516
# 29    0.005396        0.006765        0.007312
# 30    0.005312        0.006659        0.007199
# 31    0.004882        0.006119        0.006615
# 32    0.004707        0.005900        0.006378
# 33    0.004252        0.005331        0.005610
# 34    0.003829        0.004800        0.005189
# 35    0.003332        0.004177        0.004397
# 36    0.003252        0.004076        0.004406
# 37    0.002449        0.003070        0.003231
# 38    0.002218        0.002781        0.003006
